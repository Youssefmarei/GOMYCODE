# %%
# !jt -onedork
# Out:
# usage: jt [-h] [-l] [-t THEME] [-f MONOFONT] [-fs MONOSIZE] [-nf NBFONT]
#           [-nfs NBFONTSIZE] [-tf TCFONT] [-tfs TCFONTSIZE] [-dfs DFFONTSIZE]
#           [-ofs OUTFONTSIZE] [-mathfs MATHFONTSIZE] [-m MARGINS]
#           [-cursw CURSORWIDTH] [-cursc CURSORCOLOR] [-cellw CELLWIDTH]
#           [-lineh LINEHEIGHT] [-altp] [-altmd] [-altout] [-P] [-T] [-N] [-kl]
#           [-vim] [-r] [-dfonts]
# jt: error: unrecognized arguments: -onedork

# %% [markdown]
# ### Importing all used libraries and reading the dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv('titanic-passengers.csv')
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch      Ticket     Fare  Cabin Embarked
# 0        0      248740  13.0000    NaN        S
# 1        0      348123   7.6500  F G73        S
# 2        0      350050   7.8542    NaN        S
# 3        4      349909  21.0750    NaN        S
# 4        0  F.C. 12750  52.0000    B71        S
# ..     ...         ...      ...    ...      ...
# 886      0      237736  30.0708    NaN        C
# 887      0        2669   7.2292    NaN        C
# 888      0      315084   8.6625    NaN        S
# 889      0      349215   7.8958    NaN        S
# 890      0      250655  26.0000    NaN        S
#
# [891 rows x 12 columns]

# %% [markdown]
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking the sum of the nulls and filling the missing values using the fillna() function or dropping unnecessary columns/rows using the drop() and dropna() function depending on the nulls count.

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(["Cabin"], axis = 1, inplace = True)

df["Age"].fillna(df["Age"].mean(), inplace= True)

df.dropna(axis = 0, how='any', subset=['Embarked'], inplace= True)

df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Checking the data type of the columns and changing the needed ones using the LabelEncoder() function

# %%
df['Age'].apply(np.ceil)
# Out:
# 0      28.0
# 1      25.0
# 2      20.0
# 3      29.0
# 4      31.0
#        ...
# 886    14.0
# 887    22.0
# 888    30.0
# 889    30.0
# 890    19.0
# Name: Age, Length: 889, dtype: float64

# %%
df['Age']=df['Age'].astype(int)

# %%
label_encoder = LabelEncoder()
df['Sex'] = label_encoder.fit_transform(df['Sex'])
df['Embarked'] = label_encoder.fit_transform(df['Embarked'])
df['Survived'] = label_encoder.fit_transform(df['Survived'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int32
#  2   Pclass       889 non-null    int64
#  3   Name         889 non-null    object
#  4   Sex          889 non-null    int32
#  5   Age          889 non-null    int32
#  6   SibSp        889 non-null    int64
#  7   Parch        889 non-null    int64
#  8   Ticket       889 non-null    object
#  9   Fare         889 non-null    float64
#  10  Embarked     889 non-null    int32
# dtypes: float64(1), int32(4), int64(4), object(2)
# memory usage: 69.5+ KB

# %% [markdown]
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Visualising the correlation between the columns to proceed to feature selection and dropping unnecessary columns

# %%
corr = df.corr()

f, ax = plt.subplots(figsize=(12, 10))

mask = np.triu(np.ones_like(corr, dtype=bool))

cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

sns.heatmap(corr, annot=True, mask=mask, cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
df.drop(["PassengerId","Embarked"], axis = 1, inplace = True)
df
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       2                         Collander, Mr. Erik Gustaf    1
# 1           0       3                            Moen, Mr. Sigurd Hansen    1
# 2           0       3                             Jensen, Mr. Hans Peder    1
# 3           0       3        Palsson, Mrs. Nils (Alma Cornelia Berglund)    0
# 4           0       1                             Davidson, Mr. Thornton    1
# ..        ...     ...                                                ...  ...
# 886         1       2                Nasser, Mrs. Nicholas (Adele Achem)    0
# 887         0       3                              Sirayanian, Mr. Orsen    1
# 888         0       3                                Cacic, Miss. Marija    0
# 889         0       3                   Petroff, Mr. Pastcho ("Pentcho")    1
# 890         1       2  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    0
#
#      Age  SibSp  Parch      Ticket     Fare
# 0     28      0      0      248740  13.0000
# 1     25      0      0      348123   7.6500
# 2     20      0      0      350050   7.8542
# 3     29      0      4      349909  21.0750
# 4     31      1      0  F.C. 12750  52.0000
# ..   ...    ...    ...         ...      ...
# 886   14      1      0      237736  30.0708
# 887   22      0      0        2669   7.2292
# 888   30      0      0      315084   8.6625
# 889   29      0      0      349215   7.8958
# 890   19      0      0      250655  26.0000
#
# [889 rows x 9 columns]

# %% [markdown]
# # The graph below shows the count of males and females in every age band.

# %%
#Function to calculate the age band
def age_band(num):
    for i in range(1, 10):
        if num < 10*i :  return f'{(i-1) * 10} ~ {i*10}'
df['Age'].astype(int)
df['age_band'] = df['Age'].apply(age_band)
df = df.sort_values("Age")
sns.countplot(x='age_band', hue='Sex', data=df)
# Out:
# <AxesSubplot:xlabel='age_band', ylabel='count'>

# %%
a = {'Age':85, 'Survived':0, 'Sex':0}
b = {'Age':75, 'Survived':0, 'Sex':0}
df = df.append(a, ignore_index = True)
df = df.append(b, ignore_index = True)

def age_band(num):
    for i in range(1, 10):
        if num < 10*i :  return f'{(i-1) * 10} ~ {i*10}'
df['Age'].astype(int)
df['age_band'] = df['Age'].apply(age_band)
t = np.unique(np.array(df['age_band']))
x = np.arange(len(t))

mendf = df.copy()
mendf.drop(mendf[mendf['Sex'] == 0].index, inplace = True)
men_titanic_age = mendf[['age_band', 'Survived']].groupby('age_band')['Survived'].value_counts().sort_index().unstack().fillna(0)
men_titanic_age['Men Survival rate'] = men_titanic_age[1] / (men_titanic_age[0] + men_titanic_age[1]) * 100

womendf = df.copy()
womendf.drop(womendf[womendf['Sex'] == 1].index, inplace = True)
women_titanic_age = womendf[['age_band', 'Survived']].groupby('age_band')['Survived'].value_counts().sort_index().unstack().fillna(0) 
women_titanic_age['Woman Survival rate'] = women_titanic_age[1] / (women_titanic_age[0] + women_titanic_age[1]) * 100


fig, ax = plt.subplots(1, 1, figsize=(12, 10))

plt.xticks(x, t)
plt.bar(x+0.25, women_titanic_age['Woman Survival rate'], 0.5, label='Women', alpha=0.6, color='#004c70')
plt.bar(x-0.25, men_titanic_age['Men Survival rate'], 0.5, label='Men', alpha=0.6, color='#990000')
plt.xlabel("Age")
plt.ylabel("Survival Chance")
plt.title("Survival Chance Based on Sex and Age")
ax.set_facecolor('lightgrey')
plt.legend()
plt.grid(color = 'white', linestyle = '--', axis = 'y', linewidth = 0.5)
plt.show()
# Out:
# C:\Users\yusuf\AppData\Local\Temp\ipykernel_17372\2023725373.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(a, ignore_index = True)
# C:\Users\yusuf\AppData\Local\Temp\ipykernel_17372\2023725373.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(b, ignore_index = True)

# %%
df.drop(df.tail(2).index,inplace=True)

# %%
sdf = df.copy()
ddf = df.copy()
sdf.drop(sdf[sdf['Survived'] == 0].index, inplace = True)
ddf.drop(ddf[ddf['Survived'] == 1].index, inplace = True)
fig, ax =plt.subplots(1,2)
g = sns.histplot(data=sdf, x="Fare", ax=ax[0], kde=True, palette='flare')
h = sns.histplot(data=ddf, x="Fare", ax=ax[1], kde=True, palette='flare')
ax[0].set_xlim(0,500)
ax[1].set_xlim(0,500)
ax[0].set_ylim(0,300)
ax[1].set_ylim(0,300)
g.set_title('Survived', fontsize = 20)
g.set_xlabel("Fare", fontsize = 20)
g.set_ylabel("Count", fontsize = 20)
h.set_title('Dead', fontsize = 20)
h.set_xlabel("Fare", fontsize = 20)
h.set_ylabel("Count", fontsize = 20)
# Out:
# Text(0, 0.5, 'Count')

# %%
Pclass = df[['Pclass', 'Survived']].groupby('Pclass')['Survived'].value_counts().sort_index().unstack().fillna(0)
Pclass['Survival rate'] = Pclass[1] / (Pclass[0] + Pclass[1]) * 100
Pclass['Death rate'] = 100 - Pclass['Survival rate']
Pclass['Count'] = Pclass[0] + Pclass[1]
total = Pclass[0].sum() + Pclass[1].sum()
Pclass['Percentage'] = (Pclass['Count'] * 100) / total
labels=['Pclass 1', 'Pclass 2', 'Pclass 3']
Pclass
# Out:
# Survived    0    1  Survival rate  Death rate  Count  Percentage
# Pclass
# 1.0        80  134      62.616822   37.383178    214   24.071991
# 2.0        97   87      47.282609   52.717391    184   20.697413
# 3.0       372  119      24.236253   75.763747    491   55.230596

# %%
#df['Pclass'] = df['Pclass'].astype(int)
#colors = sns.color_palette('bright')[0:5]
#plt.pie(df['Pclass'].value_counts(), colors = colors, autopct='%1.1f%%')     
#############################################################################
import matplotlib.pyplot as plt
# Make data: I have 3 groups and 7 subgroups
group_names=['Pclass 1', 'Pclass 2', 'Pclass 3']
group_size=Pclass['Percentage']
subgroup_names=['Survived', 'Dead', 'Survived', 'Dead', 'Survived', 'Dead']
subgroup_size=[]
for i in range(0,3):
    subgroup_size.append((Pclass['Percentage'].iloc[i] * Pclass['Survival rate'].iloc[i]) / 100)
    subgroup_size.append((Pclass['Percentage'].iloc[i] * Pclass['Death rate'].iloc[i]) / 100)

# Create colors
a, b, c=[plt.cm.Blues, plt.cm.Reds, plt.cm.Greens]

# First Ring (outside)
fig, ax = plt.subplots()
ax.axis('equal')
mypie, _ = ax.pie(group_size, radius=1, labels=group_names, labeldistance=0.4, colors= [a(0.9), b(0.9), c(0.9)])
plt.setp( mypie, width=1, edgecolor='white')

# Second Ring (Inside)
mypie2, _ = ax.pie(subgroup_size, radius=1.3, 
labels=subgroup_names, labeldistance=1.1, colors=[a(0.8), a(0.5), b(0.8), b(0.5), c(0.8), c(0.5)], textprops={'fontsize': 8})
plt.setp( mypie2, width=0.4, edgecolor='white')
plt.margins(0,0)

subgroup_names_legs=['A.1:a1desc', 'A.2:a2desc', 'A.3:a3desc', 
'B.1:b1desc', 'B.2:b2desc', 'C.1:c1desc', 'C.2:c2desc', 'C.3:c3desc', 
'C.4:c4desc', 'C.5:c5desc']
#plt.legend(subgroup_names_legs,loc='best')
# show it
plt.show()

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
   plot_correlation_map(df)

# %% [markdown]
# The function above visualises the correlation between the columns, the correlation can be in positive or negative(direct or inverse correlation),
# 0 means no correlation,
# from 0.1 to 0.3 is weak,
# from 0.4 to 0.6 is moderate,
# from 0.7 to 0.9 is strong,
# 1 means perfect correlation

# %%
df[["Pclass", "Survived"]].groupby(["Pclass"], as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1.0     0.626168
# 2.0     0.472826
# 3.0     0.242363

# %%
title_dict = {
                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                    "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",
 
                    "Lady" :      "Royalty",
 
                    "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }

# %%
df['Title'] = df['Name'].str.split(", ", expand=True)[1]
df['Title'] = df['Title'].str.split(".", expand=True)[0]
df.drop(['Name'], axis=1, inplace=True)
df
# Out:
#      Survived  Pclass  Sex  Age  SibSp  Parch    Ticket      Fare age_band  \
# 0           1     2.0    1    0    1.0    1.0     29106   18.7500   0 ~ 10
# 1           1     3.0    0    0    2.0    1.0      2666   19.2583   0 ~ 10
# 2           1     3.0    0    0    2.0    1.0      2666   19.2583   0 ~ 10
# 3           1     1.0    1    0    1.0    2.0    113781  151.5500   0 ~ 10
# 4           1     2.0    1    0    1.0    1.0    250649   14.5000   0 ~ 10
# ..        ...     ...  ...  ...    ...    ...       ...       ...      ...
# 884         0     3.0    1   70    0.0    0.0    370369    7.7500  70 ~ 80
# 885         0     1.0    1   71    0.0    0.0  PC 17754   34.6542  70 ~ 80
# 886         0     1.0    1   71    0.0    0.0  PC 17609   49.5042  70 ~ 80
# 887         0     3.0    1   74    0.0    0.0    347060    7.7750  70 ~ 80
# 888         1     1.0    1   80    0.0    0.0     27042   30.0000  80 ~ 90
#
#       Title
# 0    Master
# 1      Miss
# 2      Miss
# 3    Master
# 4    Master
# ..      ...
# 884      Mr
# 885      Mr
# 886      Mr
# 887      Mr
# 888      Mr
#
# [889 rows x 10 columns]

# %%
sns.boxplot(x='Title', y='Age', data=df)
fig = plt.gcf()
fig.set_size_inches(25, 8)
#plt.legend(title='Survived', loc='upper right', labels=['Did NOT Survive', 'Did Survive'])
#sns.set(font_scale=1)
